# %%
Theory Questions
1.	Difference between interpreted and compiled languages:
○ Compiled languages are translated directly into machine code that the processor can execute. This translation process, called compilation, is done before the program is run. Examples include C, C++, and Java.
○ Interpreted languages, on the other hand, are not directly compiled into machine code. Instead, a program called an interpreter reads and executes the code line by line. Python, JavaScript, and Ruby are examples of interpreted languages.
2.	[cite_start]What is exception handling in Python? Exception handling is a mechanism in Python to deal with runtime errors. Instead of letting the program crash, you can catch these errors (exceptions) and execute specific code to handle them gracefully.
3.	Purpose of the finally block: The finally block in exception handling is used to execute code regardless of whether an exception was raised or not. It's typically used for cleanup actions, like closing files or network connections, ensuring that these essential operations are always performed.
4.	[cite_start]What is logging in Python? Logging is a means of tracking events that happen when a program runs. The logging module in Python provides a flexible framework for emitting log messages from applications. [cite_start]These messages can be used to diagnose problems and monitor the application's state.
5.	Significance of the __del__ method: The __del__ method is a finalizer in Python. It's called when an object is about to be destroyed by the garbage collector. While you can define it to perform cleanup tasks for an object, it's generally better to use context managers (with statement) for resource management as the exact timing of __del__'s execution is not guaranteed.
6.	[cite_start]Difference between import and from...import:
○ import module_name: This imports the entire module. You need to use the module name as a prefix to access its functions or variables (e.g., module_name.function()).
○ from module_name import function_name: This imports a specific function or variable from the module directly into the current namespace. You can then use it without the module prefix (e.g., function_name()).
7.	[cite_start]How to handle multiple exceptions: You can handle multiple exceptions in a single except block by passing a tuple of exception types. For example: except (ValueError, TypeError):. Alternatively, you can have multiple except blocks to handle different exceptions with specific logic for each.
8.	Purpose of the with statement: The with statement simplifies exception handling by encapsulating common try...finally cleanup tasks. When used with files, it automatically ensures that the file is closed when the block is exited, even if errors occur.
9.	[cite_start]Difference between multithreading and multiprocessing:
○ Multithreading: Multiple threads run within the same process, sharing the same memory space. It's useful for I/O-bound tasks where the program spends time waiting for external resources.
○ Multiprocessing: Multiple processes run independently, each with its own memory space. It's ideal for CPU-bound tasks as it can leverage multiple CPU cores to perform computations in parallel.
10.	[cite_start]Advantages of using logging: Logging provides several benefits:
○	Diagnostics: It helps in debugging and understanding how the program is executing.
○ Auditing: It can record events for security and compliance purposes.
○ Monitoring: It allows for monitoring the application's health and performance.
○ Flexibility: Log messages can be routed to different destinations (console, file, etc.) and filtered by severity level.
11.	[cite_start]What is memory management in Python? Memory management in Python is the process of allocating memory for objects and freeing it when they are no longer in use. Python handles this automatically through a combination of reference counting and a cyclic garbage collector.
12.	Basic steps in exception handling: The basic steps are:
1.	try: The code that might raise an exception is placed inside the try block.
2.	except: If an exception occurs in the try block, the corresponding except block is executed to handle the error.
3.	else (optional): This block is executed if no exceptions are raised in the try block.
4.	finally (optional): This block is always executed, regardless of whether an exception occurred.
13.	[cite_start]Why is memory management important? Effective memory management is crucial because it prevents memory leaks (where memory is not released after use), which can lead to the application consuming all available memory and crashing. It ensures the efficient use of system resources.
14.	Role of try and except:
○	try: The try block encloses the code that you suspect might cause an error.
○ except: The except block contains the code that will be executed if a specific exception is raised within the try block. It catches the exception and allows you to handle it.
15.	[cite_start]How Python's garbage collection works: Python's primary garbage collection mechanism is reference counting. Every object has a count of the number of references pointing to it. When this count drops to zero, the object's memory is deallocated. To handle reference cycles (where objects refer to each other), Python also has a cyclic garbage collector that periodically detects and cleans up these cycles.
16.	Purpose of the else block in exception handling: The else block is executed only if the try block completes without raising any exceptions. It's useful for code that should run only when the try part is successful.
17.	[cite_start]Common logging levels: The standard logging levels in increasing order of severity are:
○	DEBUG: Detailed information, typically of interest only when diagnosing problems.
○ INFO: Confirmation that things are working as expected.
○ WARNING: An indication that something unexpected happened, or a problem might occur in the near future (e.g., 'disk space low').
○ ERROR: A more serious problem that has prevented a function from performing a task.
○ CRITICAL: A very serious error, indicating that the program itself may be unable to continue running.
18.	Difference between os.fork() and multiprocessing:
○	os.fork(): This is a low-level system call available on Unix-like systems that creates a new process which is an exact copy of the parent process. Managing these processes (e.g., communication, synchronization) is manual.
○ multiprocessing module: This is a high-level Python library that provides a more convenient and portable way to create and manage processes. It offers tools for inter-process communication and synchronization, abstracting away many of the complexities of os.fork().
19.	[cite_start]Importance of closing a file: Closing a file is important because it releases the file handle back to the operating system. If you don't close a file, changes made to it may not be saved properly, and your program may run out of file descriptors if it opens too many files.
20.	[cite_start]Difference between file.read() and file.readline():
○ file.read(size): Reads the entire content of the file as a single string. If an optional size argument is provided, it reads that many bytes.
○ file.readline(): Reads a single line from the file, including the newline character at the end. It's useful for reading a file line by line.
21.	[cite_start]What is the logging module used for? The logging module in Python is used to implement a flexible event logging system for applications. It allows developers to configure logging, send log messages to different outputs, and control the verbosity of the output based on different severity levels.
22.	[cite_start]What is the os module used for in file handling? The os module provides a way of using operating system-dependent functionality. In file handling, it's used for tasks like checking if a file exists (os.path.exists()), renaming a file (os.rename()), removing a file (os.remove()), and working with directories.
23.	[cite_start]Challenges with memory management in Python: While Python's memory management is automatic, challenges can arise from reference cycles that the garbage collector might be slow to clean up, and from extensions written in C that may not properly manage memory, leading to leaks. Memory fragmentation can also be an issue in long-running applications.
24.	[cite_start]How to raise an exception manually: You can raise an exception manually using the raise keyword, followed by an exception class. For example: raise ValueError("An invalid value was provided").
25.	[cite_start]Why is it important to use multithreading? Multithreading is important in applications that need to remain responsive while performing long-running tasks, particularly those that are I/O-bound (like network requests or file operations). It allows the application to perform other tasks while one thread is waiting, improving user experience and overall throughput.
Practical Questions
1.	[cite_start]Open a file for writing and write a string to it. with open('my_file.txt', 'w') as f:
    f.write("Hello, this is a test string.\n")
2.	[cite_start]Read the contents of a file and print each line. try:     with open('my_file.txt', 'r') as f:         for line in f:
            print(line, end='') except FileNotFoundError:     print("Error: The file was not found.")
3.	[cite_start]Handle a case where the file doesn't exist. try:     with open('non_existent_file.txt', 'r') as f:         content = f.read()         print(content) except FileNotFoundError:
    print("Error: The specified file could not be found.")
4.	[cite_start]Read from one file and write its content to another. try:
    with open('source.txt', 'r') as source_file, open('destination.txt', 'w') as dest_file:
        content = source_file.read()         dest_file.write(content) except FileNotFoundError:
    print("Error: The source file was not found.")
5.	[cite_start]Catch and handle division by zero error. try:
    result = 10 / 0 except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
6.	[cite_start]Log an error message when a division by zero occurs.
import logging
 logging.basicConfig(filename='error.log', level=logging.ERROR)
 try:
    result = 10 / 0 except ZeroDivisionError as e:
    logging.error(f"An error occurred: {e}")
    print("A division error occurred. See error.log for details.")
7.	[cite_start]Log information at different levels. import logging
 logging.basicConfig(level=logging.INFO, format='%(levelname)s:
%(message)s')
 logging.info("This is an informational message.") logging.warning("This is a warning message.") logging.error("This is an error message.")
8.	[cite_start]Handle a file opening error. try:
    with open('another_non_existent.txt', 'r') as f:         print(f.read()) except FileNotFoundError:
    print("Error: Could not open the file because it does not exist.")

9.	[cite_start]Read a file line by line and store it in a list. lines_list = [] try:     with open('my_file.txt', 'r') as f:
        lines_list = f.readlines()     # To remove newline characters:
    # lines_list = [line.strip() for line in lines_list]     print(lines_list) except FileNotFoundError:
    print("Error: File not found.")

10.	[cite_start]Append data to an existing file. with open('my_file.txt', 'a') as f:
    f.write("This is an appended line.\n")
11.	[cite_start]Handle a KeyError for a dictionary. my_dict = {'a': 1, 'b': 2} try:
    value = my_dict['c'] except KeyError:
    print("Error: The key does not exist in the dictionary.")
12.	[cite_start]Use multiple except blocks. try:
    # Change the value of x to test different exceptions     x = 'a'      if x == 0:
        result = 10 / x     elif isinstance(x, str):
        result = int(x) except ZeroDivisionError:
    print("Error: Division by zero.") except TypeError:
    print("Error: Type mismatch for operation.") except ValueError:
    print("Error: Cannot convert string to integer.")
13.	[cite_start]Check if a file exists before reading. import os  if os.path.exists('my_file.txt'):     with open('my_file.txt', 'r') as f:         print(f.read()) else:
    print("The file does not exist.")

14.	[cite_start]Log both informational and error messages. import logging
 logging.basicConfig(filename='app.log', level=logging.INFO,                      format='%(asctime)s - %(levelname)s -
%(message)s')
 logging.info("Program started.") try:
    result = 10 / 0 except ZeroDivisionError:
    logging.error("Division by zero error occurred.") logging.info("Program finished.")

15.	[cite_start]Handle the case of an empty file. import os  try:     if os.path.getsize('empty_file.txt') == 0:         print("The file is empty.")     else:         with open('empty_file.txt', 'r') as f:             print(f.read()) except FileNotFoundError:
    print("Error: File not found.")
except OSError: # Handles cases where getsize fails     print("The file is empty or does not exist.")

16.	[cite_start]Demonstrate memory profiling.
# Note: You need to install memory_profiler: pip install memory_profiler
from memory_profiler import profile
@profile def my_function():
    a = [1] * (10 ** 6)     b = [2] * (2 * 10 ** 7)     del b     return a
 if __name__ == '__main__':     my_function()

17.	[cite_start]Create and write a list of numbers to a file. numbers = [10, 20, 30, 40, 50] with open('numbers.txt', 'w') as f:     for num in numbers:
        f.write(f"{num}\n")

18.	[cite_start]Implement logging with file rotation. import logging
from logging.handlers import RotatingFileHandler
 log_handler = RotatingFileHandler('rotated_app.log', maxBytes=1*1024*1024, backupCount=5) logging.basicConfig(handlers=[log_handler], level=logging.INFO,                     format='%(asctime)s - %(levelname)s -
%(message)s')
 logging.info("This is the first log message.") # Add more logging to trigger rotation if needed
19.	[cite_start]Handle both IndexError and KeyError. my_list = [1, 2, 3] my_dict = {'a': 1}
 try:
    # Test IndexError     print(my_list[5])      # Test KeyError     # print(my_dict['b'])  except (IndexError, KeyError) as e:
    print(f"An error occurred: {type(e).__name__} - {e}")
20.	[cite_start]Open and read a file using a context manager. try:     with open('my_file.txt', 'r') as f:         content = f.read()         print(content) except FileNotFoundError:
    print("Error: The file was not found.")
21.	[cite_start]Count occurrences of a specific word in a file. word_to_find = "is" count = 0 try:     with open('my_file.txt', 'r') as f:         for line in f:
            words = line.split()             count += words.count(word_to_find)
    print(f"The word '{word_to_find}' appears {count} times.") except FileNotFoundError:
    print("Error: The file was not found.")
22.	[cite_start]Check if a file is empty before reading. import os
 file_path = 'my_file.txt' if os.path.exists(file_path) and os.path.getsize(file_path) > 0:     with open(file_path, 'r') as f:         content = f.read()         print("File content:\n", content) else:
    print(f"The file '{file_path}' is empty or does not exist.")
23.	[cite_start]Write to a log file when a file handling error occurs. import logging
 logging.basicConfig(filename='file_errors.log', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s -
%(message)s')
 try:     with open('non_existent_file.txt', 'r') as f:         f.read() except FileNotFoundError as e:
    logging.error(f"File handling error: {e}")     print("A file error occurred. Check file_errors.log for details.")
